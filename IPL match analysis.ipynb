# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("matches - matches.csv")
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
winner_column = df["winner"]
winner_column
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
df[ ["team1", "team2","winner"] ].head()
# Out:
#                          team1                        team2  \
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1               Mumbai Indians       Rising Pune Supergiant
# 2                Gujarat Lions        Kolkata Knight Riders
# 3       Rising Pune Supergiant              Kings XI Punjab
# 4  Royal Challengers Bangalore             Delhi Daredevils
#
#                         winner
# 0          Sunrisers Hyderabad
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 3              Kings XI Punjab
# 4  Royal Challengers Bangalore

# %%
df.iloc[[1,4,9]] #fensy Indexd
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 1           0       Rising Pune Supergiant            0               7
# 4           0  Royal Challengers Bangalore           15               0
# 9           0               Mumbai Indians            0               4
#
#   player_of_match                                    venue         umpire1  \
# ...

# %%
df.iloc[ 1 : 8 : 2]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
# ...

# %%
df.iloc[ : , [4,5,10]].head() # df[ ["team1", "team2","winner"] ].head()
# Out:
#                          team1                        team2  \
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1               Mumbai Indians       Rising Pune Supergiant
# 2                Gujarat Lions        Kolkata Knight Riders
# 3       Rising Pune Supergiant              Kings XI Punjab
# 4  Royal Challengers Bangalore             Delhi Daredevils
#
#                         winner
# 0          Sunrisers Hyderabad
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 3              Kings XI Punjab
# 4  Royal Challengers Bangalore

# %%
mask = df["city"] == "Gujarat Lions"
mask.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: city, dtype: bool

# %%
df[mask]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
def get_city_counter(city):
        mask =  df["city"] == city
        return df[mask].shape
get_city_counter("Rajkot")
# Out:
# (10, 18)

# %%
def get_city_winner_team(city):
    global new_df_city
    mask =  df["city"] == city
    new_df_city = df[mask]
   # mask2 = new_df_city["winner"] == win
    
    return new_df_city.shape
    
get_city_winner_team("Kolkata")
# Out:
# (61, 18)

# %%
def get_city_winner_team1(win):
    global new_df_city
    mask2 =  new_df_city["winner"] == win
    new_df_city = new_df_city[mask2]
   # mask2 = new_df_city["winner"] == win
    
    return new_df_city.shape
    
get_city_winner_team1("Kolkata Knight Riders")
# Out:
# (37, 18)

# %%
mask1 = df["city"] == "Hyderabad"
mask2 = df["date"] > "2017-01-01"
df[mask1 & mask2].shape
# Out:
# (8, 18)

# %%
df["winner"].value_counts().head()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: count, dtype: int64

# %%
df["winner"].value_counts().head().plot(kind = "barh")
# Out:
# <Axes: ylabel='winner'>

# %%
df["toss_decision"].value_counts().head().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["win_by_runs"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["city"].value_counts().head()
# Out:
# city
# Mumbai       85
# Bangalore    66
# Kolkata      61
# Delhi        60
# Hyderabad    49
# Name: count, dtype: int64

# %%
df["city"].value_counts()["Hyderabad"]
# Out:
# 49

# %%
df["city"].value_counts().index
# Out:
# Index(['Mumbai', 'Bangalore', 'Kolkata', 'Delhi', 'Hyderabad', 'Chennai',
#        'Chandigarh', 'Jaipur', 'Pune', 'Durban', 'Ahmedabad', 'Centurion',
#        'Visakhapatnam', 'Rajkot', 'Dharamsala', 'Johannesburg', 'Cape Town',
#        'Abu Dhabi', 'Ranchi', 'Port Elizabeth', 'Cuttack', 'Raipur', 'Sharjah',
#        'Kochi', 'Indore', 'Kanpur', 'Nagpur', 'Kimberley', 'East London',
#        'Bloemfontein'],
#       dtype='object', name='city')

# %%
df["city"].value_counts().values
# Out:
# array([85, 66, 61, 60, 49, 48, 46, 33, 32, 15, 12, 12, 11, 10,  9,  8,  7,
#         7,  7,  7,  7,  6,  6,  5,  5,  4,  3,  3,  3,  2])

# %%
df["team1"].value_counts() + df["team2"].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %%
df.drop_duplicates(subset = "city").shape
# Out:
# (31, 18)

# %%
df.drop_duplicates(subset = ["season"], keep = "last")[["season","winner"]].sort_values("season")
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %% [markdown]
# # Practise

# %%
df["winner"].value_counts().index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
df["winner"].value_counts().values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.drop_duplicates(subset= "season", keep = "last")[["season","winner"]].sort_values("season")
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
mask8 = df["season"] == 2008
len(df[mask8].drop_duplicates(subset = "team1")["team1"])
# Out:
# 8

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
city = df.groupby("city")

# %%
len(city)
# Out:
# 30

# %%
df.drop_duplicates(subset = "city").shape
# Out:
# (31, 18)

# %%
city.size()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
df.value_counts("city").shape
# Out:
# (30,)

# %%
city.size().sort_values(ascending= False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Cuttack            7
# Ranchi             7
# Port Elizabeth     7
# Abu Dhabi          7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# dtype: int64

# %%
city.last()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       476    2014  2014-04-29             Rajasthan Royals
# Ahmedabad       540    2015  2015-04-24             Rajasthan Royals
# Bangalore       636    2016  2016-05-29          Sunrisers Hyderabad
# Bloemfontein    165    2009  2009-05-17             Delhi Daredevils
# Cape Town       130    2009  2009-04-26              Kings XI Punjab
# Centurion       172    2009  2009-05-22             Delhi Daredevils
# Chandigarh      622    2016  2016-05-15              Kings XI Punjab
# Chennai         563    2015  2015-05-10          Chennai Super Kings
# Cuttack         497    2014  2014-05-14               Mumbai Indians
# Delhi           635    2016  2016-05-27                Gujarat Lions
# Dharamsala      450    2013  2013-05-18              Kings XI Punjab
# Durban          169    2009  2009-05-20          Chennai Super Kings
# ...

# %%
city.groups
# Out:
# {'Abu Dhabi': [457, 459, 460, 464, 470, 471, 475], 'Ahmedabad': [179, 186, 194, 197, 481, 486, 497, 500, 525, 532, 535, 539], 'Bangalore': [4, 11, 16, 29, 41, 44, 56, 57, 59, 69, 73, 83, 89, 103, 110, 180, 183, 191, 196, 213, 216, 225, 241, 267, 279, 282, 290, 301, 311, 316, 325, 328, 349, 355, 366, 378, 382, 391, 400, 406, 410, 428, 431, 451, 480, 487, 491, 494, 509, 516, 524, 533, 537, 545, 549, 556, 570, 579, 586, 605, 610, 616, 619, 625, 632, 635], 'Bloemfontein': [160, 164], 'Cape Town': [117, 118, 119, 120, 123, 125, 129], 'Centurion': [132, 135, 136, 146, 147, 148, 155, 156, 165, 169, 170, 171], 'Chandigarh': [31, 34, 45, 47, 60, 68, 72, 80, 93, 96, 107, 176, 192, 195, 204, 214, 242, 255, 283, 286, 320, 329, 332, 339, 353, 365, 390, 399, 408, 435, 439, 447, 504, 508, 511, 543, 551, 565, 568, 578, 585, 588, 596, 611, 614, 621], 'Chennai': [66, 70, 78, 84, 90, 106, 109, 178, 189, 201, 205, 210, 221, 223, 234, 247, 261, 271, 275, 288, 296, 305, 306, 307, 319, 331, 333, 342, 346, 
# ...

# %%
df.iloc[457]
# Out:
# id                                   458
# season                              2014
# city                           Abu Dhabi
# date                          2014-04-16
# team1              Kolkata Knight Riders
# team2                     Mumbai Indians
# toss_winner        Kolkata Knight Riders
# toss_decision                        bat
# result                            normal
# dl_applied                             0
# winner             Kolkata Knight Riders
# win_by_runs                           41
# win_by_wickets                         0
# player_of_match                JH Kallis
# venue               Sheikh Zayed Stadium
# umpire1                        M Erasmus
# umpire2                   RK Illingworth
# umpire3                              NaN
# Name: 457, dtype: object

# %%
city.get_group("Mumbai")
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..   ...     ...     ...         ...                          ...
# 572  573    2015  Mumbai  2015-05-19               Mumbai Indians
# 576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2       toss_winner toss_decision  result  \
# 6             Mumbai Indians    Mumbai Indians         field  normal
# ...

# %%
city.sum()
# Out:
#                    id  season  \
# city
# Abu Dhabi        3263   14098
# Ahmedabad        4863   24156
# Bangalore       22299  132861
# Bloemfontein      326    4018
# Cape Town         858   14063
# Centurion        1842   24108
# Chandigarh      15325   92582
# Chennai         15096   96554
# Cuttack          2534   14086
# Delhi           19600  120771
# Dharamsala       2949   18103
# Durban           2147   30135
# East London       432    6027
# Hyderabad       15907   98649
# Indore            618   10073
# Jaipur           9210   66363
# Johannesburg     1279   16072
# Kanpur           1358    8066
# Kimberley         458    6027
# Kochi            1301   10055
# Kolkata         19973  122783
# Mumbai          26283  171049
# Nagpur            646    6030
# Port Elizabeth    980   14063
# Pune            11238   64455
# Raipur           3229   12088
# Rajkot           3075   20165
# Ranchi           3439   14097
# Sharjah          2804   12084
# ...

# %%
df.head().shape
# Out:
# (5, 18)

# %% [markdown]
# # New Data set of IPL Runs

# %%
df1 = pd.read_csv("deliveries.csv")
df1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df1.groupby("batsman")

# %%
runs = df1.groupby("batsman")
runs

# %%
runs.get_group("V Kohli").head()
# Out:
#       match_id  inning                 batting_team    bowling_team  over  \
# 2590        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2591        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2593        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2594        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2597        12       1  Royal Challengers Bangalore  Mumbai Indians     2
#
#       ball  batsman non_striker           bowler  is_super_over  ...  \
# 2590     2  V Kohli    CH Gayle       TG Southee              0  ...
# 2591     3  V Kohli    CH Gayle       TG Southee              0  ...
# 2593     5  V Kohli    CH Gayle       TG Southee              0  ...
# 2594     6  V Kohli    CH Gayle       TG Southee              0  ...
# 2597     1  V Kohli    CH Gayle  Harbhajan Singh              0  ...
#
#       bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
runs["batsman_runs"].sum().sort_values(ascending = False)
# Out:
# batsman
# SK Raina        4548
# V Kohli         4423
# RG Sharma       4207
# G Gambhir       4132
# DA Warner       4014
#                 ...
# Abdur Razzak       0
# S Kaushik          0
# S Ladda            0
# U Kaul             0
# RR Bhatkal         0
# Name: batsman_runs, Length: 461, dtype: int64

# %%
runs.size()
# Out:
# batsman
# A Ashish Reddy     196
# A Chandila           7
# A Chopra            75
# A Choudhary         20
# A Flintoff          57
#                   ...
# YV Takawale        183
# Yashpal Singh       67
# Younis Khan          7
# Yuvraj Singh      2050
# Z Khan             141
# Length: 461, dtype: int64

# %%
df1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
batsman = df1.groupby("batsman")
batsman

# %%
batsman.size()["V Kohli"]
# Out:
# 3494

# %%
batsman.get_group("V Kohli").head()
# Out:
#       match_id  inning                 batting_team    bowling_team  over  \
# 2590        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2591        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2593        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2594        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2597        12       1  Royal Challengers Bangalore  Mumbai Indians     2
#
#       ball  batsman non_striker           bowler  is_super_over  ...  \
# 2590     2  V Kohli    CH Gayle       TG Southee              0  ...
# 2591     3  V Kohli    CH Gayle       TG Southee              0  ...
# 2593     5  V Kohli    CH Gayle       TG Southee              0  ...
# 2594     6  V Kohli    CH Gayle       TG Southee              0  ...
# 2597     1  V Kohli    CH Gayle  Harbhajan Singh              0  ...
#
#       bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
batsman["batsman_runs"].sum().sort_values(ascending = False).head(10)
# Out:
# batsman
# SK Raina          4548
# V Kohli           4423
# RG Sharma         4207
# G Gambhir         4132
# DA Warner         4014
# RV Uthappa        3778
# CH Gayle          3651
# S Dhawan          3561
# MS Dhoni          3560
# AB de Villiers    3486
# Name: batsman_runs, dtype: int64

# %%
df1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
mask_6 = df1["batsman_runs"] == 6
batsman_sixes = df1[mask_6].groupby("batsman")
batsman_sixes.size().sort_values(ascending = False)
# Out:
# batsman
# CH Gayle         266
# SK Raina         174
# RG Sharma        173
# V Kohli          160
# DA Warner        160
#                 ...
# CK Langeveldt      1
# CR Woakes          1
# P Sahu             1
# DE Bollinger       1
# Basil Thampi       1
# Length: 301, dtype: int64

# %% [markdown]
# # Find top three teams where VK had got highest runs.

# %%
df1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
mask_3th_runs = df1["batsman"] == "V Kohli"
vk_runs = df1[mask_3th_runs]
vk_runs.head()
# Out:
#       match_id  inning                 batting_team    bowling_team  over  \
# 2590        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2591        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2593        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2594        12       1  Royal Challengers Bangalore  Mumbai Indians     1
# 2597        12       1  Royal Challengers Bangalore  Mumbai Indians     2
#
#       ball  batsman non_striker           bowler  is_super_over  ...  \
# 2590     2  V Kohli    CH Gayle       TG Southee              0  ...
# 2591     3  V Kohli    CH Gayle       TG Southee              0  ...
# 2593     5  V Kohli    CH Gayle       TG Southee              0  ...
# 2594     6  V Kohli    CH Gayle       TG Southee              0  ...
# 2597     1  V Kohli    CH Gayle  Harbhajan Singh              0  ...
#
#       bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %%
VK_Total_matches_per_team = vk_runs.groupby("bowling_team")

# %%
VK_Total_matches_per_team["batsman_runs"].sum().sort_values(ascending = False)
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64
